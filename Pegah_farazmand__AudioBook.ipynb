# %% [markdown]
# # Create an Audiobook from a PDF
# ## This task tests your ability to apply Text to Speech conversion and Extraction of Text from PDF files in the creation of an audiobook from a PDF file

# %% [markdown]
# ### Steps
# - Extract text from PDF file
# - Clean the text
# - Convert the text into speech
# - Save the speech
# - Play the speech

# %% [markdown]
# ## 1. Extract text from PDF
# - Use PyPDF2

# %% [markdown]
# ### Install the library

# %%
! pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Import the library

# %%
import PyPDF2

# %% [markdown]
# ### Extract the text

# %%
file_path = "/content/exam.pdf"

with open(file_path, "rb") as file:
    reader = PyPDF2.PdfReader(file)
    extracted_text = ""
    for page in reader.pages:
        extracted_text += page.extract_text()

print(extracted_text[:1000])
# Out:
# Hello!
# Hi there!
# Good morning, good afternoon, good evening —wherever and whenever you're reading or
# hearing this, I want to take a moment to extend the warmest, most sincere greeting I can
# offer. I hope this message finds you well, feeling peaceful, grounded, and open to w hat lies
# ahead.
# Sometimes a simple “hello” doesn’t feel like enough. Sometimes we want more than just a
# word—we want connection, acknowledgment, presence. That’s what I intend to give you
# with this greeting: not just a word, but a bridge. A bridge between you and me. Betw een
# your world and mine. Between hearts that may not have met yet but are already open to
# one another.
# So again, hello. Truly. Deeply. Honestly —hello.
# In this fast -paced world we live in, where people often move past each other with barely a
# glance, saying "hello" can feel radical. It's not just a social nicety; it’s an invitation to be
# ...

# %% [markdown]
# ### Print the extracted text

# %% [markdown]
# ## 2. Convert the Text into Speech
# - Use **pyttsx3** OR **gTTS**

# %% [markdown]
# ### Install the library

# %%
# !pip install pyttsx3

# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...

# %% [markdown]
# ### Import the library

# %%
from gtts import gTTS
tts = gTTS(text=extracted_text[:3000], lang='en')
tts.save("audiobook.mp3")

# %%
from IPython.display import Audio
Audio("audiobook.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#i did this in google colab

# %% [markdown]
# ### Initialize a Speaker object

# %% [markdown]
# ### Convert the text

# %% [markdown]
# ### Save the audio
